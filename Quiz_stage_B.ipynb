# %%
#import all neccessary libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#read the energy dataset
energy_df = pd.read_csv("energy_Data.csv")
energy_df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
#display columns
energy_df.columns
# Out:
# Index(['date', 'Appliances', 'lights', 'T1', 'RH_1', 'T2', 'RH_2', 'T3',
#        'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8',
#        'RH_8', 'T9', 'RH_9', 'T_out', 'Press_mm_hg', 'RH_out', 'Windspeed',
#        'Visibility', 'Tdewpoint', 'rv1', 'rv2'],
#       dtype='object')

# %%
#drop the lights and date columns
energy_data = energy_df.drop(["date","lights"],axis =1)
energy_data.head()
# Out:
#    Appliances     T1       RH_1    T2       RH_2     T3       RH_3         T4  \
# 0          60  19.89  47.596667  19.2  44.790000  19.79  44.730000  19.000000
# 1          60  19.89  46.693333  19.2  44.722500  19.79  44.790000  19.000000
# 2          50  19.89  46.300000  19.2  44.626667  19.79  44.933333  18.926667
# 3          50  19.89  46.066667  19.2  44.590000  19.79  45.000000  18.890000
# 4          60  19.89  46.333333  19.2  44.530000  19.79  45.000000  18.890000
#
#         RH_4         T5  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  45.566667  17.166667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  45.992500  17.166667  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  45.890000  17.166667  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  45.723333  17.166667  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  45.530000  17.200000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %%
#displays the info of the dataframe
energy_data.info()
#there are no missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19735 entries, 0 to 19734
# Data columns (total 27 columns):
# Appliances     19735 non-null int64
# T1             19735 non-null float64
# RH_1           19735 non-null float64
# T2             19735 non-null float64
# RH_2           19735 non-null float64
# T3             19735 non-null float64
# RH_3           19735 non-null float64
# T4             19735 non-null float64
# RH_4           19735 non-null float64
# T5             19735 non-null float64
# RH_5           19735 non-null float64
# T6             19735 non-null float64
# RH_6           19735 non-null float64
# T7             19735 non-null float64
# RH_7           19735 non-null float64
# T8             19735 non-null float64
# RH_8           19735 non-null float64
# T9             19735 non-null float64
# RH_9           19735 non-null float64
# T_out          19735 non-null float64
# Press_mm_hg    19735 non-null float64
# RH_out         19735 non-null float64
# ...

# %%
#the summary statistics
energy_data.describe()
# Out:
#          Appliances            T1          RH_1            T2          RH_2  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      97.694958     21.686571     40.259739     20.341219     40.420420
# std      102.524891      1.606066      3.979299      2.192974      4.069813
# min       10.000000     16.790000     27.023333     16.100000     20.463333
# 25%       50.000000     20.760000     37.333333     18.790000     37.900000
# 50%       60.000000     21.600000     39.656667     20.000000     40.500000
# 75%      100.000000     22.600000     43.066667     21.500000     43.260000
# max     1080.000000     26.260000     63.360000     29.856667     56.026667
#
#                  T3          RH_3            T4          RH_4            T5  \
# count  19735.000000  19735.000000  19735.000000  19735.000000  19735.000000
# mean      22.267611     39.242500     20.855335     39.026904     19.592106
# ...

# %%
#normalise the dataset to a uniform scale using the min max scale
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()#instantiate the min max scaler
#then we fit,transform 
#and also convert to a dataframe since it comes as a numpy array
norm_data = pd.DataFrame(scaler.fit_transform(energy_data),columns=energy_data.columns)

# %%
norm_data.head()
# Out:
#    Appliances       T1      RH_1        T2      RH_2        T3      RH_3  \
# 0    0.046729  0.32735  0.566187  0.225345  0.684038  0.215188  0.746066
# 1    0.046729  0.32735  0.541326  0.225345  0.682140  0.215188  0.748871
# 2    0.037383  0.32735  0.530502  0.225345  0.679445  0.215188  0.755569
# 3    0.037383  0.32735  0.524080  0.225345  0.678414  0.215188  0.758685
# 4    0.046729  0.32735  0.531419  0.225345  0.676727  0.215188  0.758685
#
#          T4      RH_4        T5  ...        T9      RH_9     T_out  \
# 0  0.351351  0.764262  0.175506  ...  0.223032  0.677290  0.372990
# 1  0.351351  0.782437  0.175506  ...  0.226500  0.678532  0.369239
# 2  0.344745  0.778062  0.175506  ...  0.219563  0.676049  0.365488
# 3  0.341441  0.770949  0.175506  ...  0.219563  0.671909  0.361736
# 4  0.341441  0.762697  0.178691  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %% [markdown]
# # Question 12
# From the dataset, fit a linear model on the relationship between the temperature in the living room in Celsius (x = T2) and the temperature outside the building (y = T6). What is the R^2 value in two D.P

# %%
#select the features and pass them as numpy arrays
X = np.array(norm_data[["T2"]]) #the predictor
y = np.array(norm_data[["T6"]] )# the target

# %%
#split the data into train and test set
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size =0.3,random_state=42)

# %%
#fit the train sets
reg = LinearRegression()#instantiate the regression object
#fit the model to the train sets
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#obtain predictions using the test sets
reg_prediction = reg.predict(X_test)

# %%
reg_prediction
# Out:
# array([[0.23928945],
#        [0.46794238],
#        [0.23108472],
#        ...,
#        [0.3001772 ],
#        [0.4297256 ],
#        [0.3217686 ]])

# %%
#to get the weight of the regression
reg_coefficient = reg.coef_ #returns an array

# %%
#we index 
reg_coefficient[0]
# Out:
# array([0.8910771])

# %%
#the intercept
reg.intercept_
# Out:
# array([0.13176428])

# %%
accuracy  = reg.score(X_test,y_test)
round(accuracy,2)
# Out:
# 0.64

# %%
#generate the features data from the normalised dataset by dropping the target
X = norm_data.drop(["Appliances"],axis = 1)

# %%
#generate the target dataframe
y = norm_data["Appliances"]

# %%
#split the normalised data into train and test sets
X_train, X_test,y_train,y_test= train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
#the shape of each set
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (13814, 26)
# (5921, 26)
# (13814,)
# (5921,)

# %%
#fit the train sets
reg = LinearRegression()#instantiate the regression object
#fit the model to the train sets
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#obtain predictions using the test sets
reg_prediction = reg.predict(X_test)
reg_prediction
# Out:
# array([0.03322207, 0.24411599, 0.03400024, ..., 0.06844707, 0.10032325,
#        0.05722198])

# %%
#import sklearn libraries
from sklearn.linear_model import Lasso, Ridge
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# # Question 13
#
# What is the Mean Absolute Error (in two decimal places)?

# %%
#calculating the MAE for linear regression
reg_mae = mean_absolute_error(y_test,reg_prediction)
round(reg_mae,2)
# Out:
# 0.05

# %% [markdown]
# # Question 14
# What is the Residual Sum of Squares (in two decimal places)?

# %%
#calculating rss
reg_rss = np.sum(np.square(y_test - reg_prediction))
round(reg_rss, 2)
# Out:
# 45.35

# %% [markdown]
# # Question 15
#
# What is the Root Mean Squared Error (in three decimal places)?

# %%
#calculating the root mean squared error for the linear regression
reg_rmse=np.sqrt(mean_squared_error(y_test,reg_prediction))
round(reg_rmse,3)
# Out:
# 0.088

# %% [markdown]
# # Question 16
#
# What is the Coefficient of Determination (in two decimal places)?

# %%
#calculating the r square of the linear regression
reg_r2 = r2_score(y_test,reg_prediction)
round(reg_r2,2)
# Out:
# 0.15

# %% [markdown]
# Question 17
#
# Obtain the feature weights from your linear model above. Which features have the lowest and highest weights respectively?
#
# **rh2 and rh1**

# %%
#comparing the effects of regularisation
def get_weights_df(model, feat, col_name):
    #this function returns the weight of every feature
    weights = pd.Series(model.coef_, feat.columns).sort_values()
    weights_df = pd.DataFrame(weights).reset_index()
    weights_df.columns = ['Features', col_name]
    weights_df[col_name].round(3)
    return weights_df
    #the higher the weight, the more important it is in predicting the values

# %%
linear_model_weights = get_weights_df(reg, X_train, 'Linear_Model_Weight')
linear_model_weights
# Out:
#        Features  Linear_Model_Weight
# 0          RH_2            -0.456698
# 1         T_out            -0.321860
# 2            T2            -0.236178
# 3            T9            -0.189941
# 4          RH_8            -0.157595
# 5        RH_out            -0.077671
# 6          RH_7            -0.044614
# 7          RH_9            -0.039800
# 8            T5            -0.015657
# 9            T1            -0.003281
# 10          rv1             0.000770
# 11          rv2             0.000770
# 12  Press_mm_hg             0.006839
# 13           T7             0.010319
# 14   Visibility             0.012307
# 15         RH_5             0.016006
# 16         RH_4             0.026386
# 17           T4             0.028981
# 18    Windspeed             0.029183
# 19         RH_6             0.038049
# 20         RH_3             0.096048
# 21           T8             0.101995
# 22    Tdewpoint             0.117758
# 23           T6             0.236425
# ...

# %% [markdown]
# # Question 18
#
# Train a ridge regression model with an alpha value of 0.4. Is there any change to the root mean squared error (RMSE) when evaluated on the test set?
#
# **no change**

# %%
#use a ridge regression to train
ridge_reg = Ridge(alpha=0.4)
#fit ridge_reg
ridge_reg.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
#use a ridge regression to predict
ridge_predict = ridge_reg.predict(X_test)
ridge_predict
# Out:
# array([0.03321872, 0.24043824, 0.03461337, ..., 0.06872351, 0.10025536,
#        0.05851175])

# %%
#calculating the root mean square for the ridge regression
ridge_rmse = np.sqrt(mean_squared_error(y_test,ridge_predict))
round(ridge_rmse,3)
# Out:
# 0.088

# %%
#calculating the root mean squared error for the linear regression
reg_rmse=np.sqrt(mean_squared_error(y_test,reg_prediction))
round(reg_rmse,3)
# Out:
# 0.088

# %% [markdown]
# # Question 19
# Train a lasso regression model with an alpha value of 0.001 and obtain the new feature weights with it. How many of the features have non-zero feature weights
#
# **4**

# %%
#use a lasso regression 
lasso_reg = Lasso(alpha=0.001)
#fit lasso_reg
lasso_reg.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
lasso_predict  = lasso_reg.predict(X_test)
lasso_predict
# Out:
# array([0.07370267, 0.08143458, 0.07716072, ..., 0.07792848, 0.09034412,
#        0.08359255])

# %%
lasso_weights_df = get_weights_df(lasso_reg, X_train, 'Lasso_weight')
lasso_weights_df
# Out:
#        Features  Lasso_weight
# 0        RH_out     -0.049557
# 1          RH_8     -0.000110
# 2            T1      0.000000
# 3     Tdewpoint      0.000000
# 4    Visibility      0.000000
# 5   Press_mm_hg     -0.000000
# 6         T_out      0.000000
# 7          RH_9     -0.000000
# 8            T9     -0.000000
# 9            T8      0.000000
# 10         RH_7     -0.000000
# 11          rv1     -0.000000
# 12           T7     -0.000000
# 13           T6      0.000000
# 14         RH_5      0.000000
# 15           T5     -0.000000
# 16         RH_4      0.000000
# 17           T4     -0.000000
# 18         RH_3      0.000000
# 19           T3      0.000000
# 20         RH_2     -0.000000
# 21           T2      0.000000
# 22         RH_6     -0.000000
# 23          rv2     -0.000000
# 24    Windspeed      0.002912
# 25         RH_1      0.017880

# %% [markdown]
# # Question 20
#
# What is the new RMSE with the Lasso Regression (in 3 decimal places)?

# %%
#calculate the root mean square for the lasso regression
lasso_rmse = np.sqrt(mean_squared_error(y_test,lasso_predict))
round(lasso_rmse,3)
# Out:
# 0.094

# %%
#all weights merged together
final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')
final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2            -0.456698     -0.411071     -0.000000
# 1         T_out            -0.321860     -0.262172      0.000000
# 2            T2            -0.236178     -0.201397      0.000000
# 3            T9            -0.189941     -0.188916     -0.000000
# 4          RH_8            -0.157595     -0.156830     -0.000110
# 5        RH_out            -0.077671     -0.054724     -0.049557
# 6          RH_7            -0.044614     -0.045977     -0.000000
# 7          RH_9            -0.039800     -0.041367     -0.000000
# 8            T5            -0.015657     -0.019853     -0.000000
# 9            T1            -0.003281     -0.018406      0.000000
# 10          rv1             0.000770      0.000748     -0.000000
# 11          rv2             0.000770      0.000748     -0.000000
# 12  Press_mm_hg             0.006839      0.006584     -0.000000
# ...
